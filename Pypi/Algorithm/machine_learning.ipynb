# %% [markdown]
# - ### Machine learning
#
# 0. Paradigm
#
#     0.1. supervised learning -- static
#
#     0.2. unsupervised learning -- static
#
#     0.3. reinforcement learning-- dynamic
#
# 1. Tradtional algorithm
#
#     1.1. supervised with label
#
#     1.1.1. categorisation
#
#         logistic regression, SVM
#
#         decision tree, random forest, XGboost/LightGBM
#
#     1.1.2. regression
#
#         linear regression, SVR
#
#     1.2. non-supervised without label
#
#     1.2.1. clustering
#
#         K-means, DBSCAN
#
#     1.2.2. dimensionality
#
#         PCA
#
#     1.2.3. association
#
#         apriori
#
# 2. reinforcement learning
#
#         Q-Learning, Deep Q-Network
#
# 3. Deep learning
#
#     3.1. CNN
#
#         ResNet, VGG, YOLO
#
#     3.2. RNN
#
#         ​​LSTM / GRU, Transformer​​
#
#     3.3. GAN
#
#     3.4 Diffusion
#
#
# ---
