# %% [markdown]
# - ### pip
#
# 1. [Version and location](#version-and-location)
#
# 2. [Lib list](#lib-list)
#
# 3. [Install a package](#install-a-package)
#
# 4. [Install/uninstall a package](#installuninstall-a-package)
#
# 5. [Upgrade packages](#upgrade-packages)
#
# 6. [Export packages version](#export-packages-version)

# %% [markdown]
# ---

# %% [markdown]
# - ### Version and location
#
# 1. pip
#
# ```pip --version ```
#
# 2. packages
#
# ```pip show *package_name*```

# %% [markdown]
# ---

# %% [markdown]
# - ### Lib list
#
# 1. lib list
#
# ```pip list```
#
# 2. lib list (with outdated)
#
# ```pip list -o```

# %% [markdown]
# ---

# %% [markdown]
# - #### Install/uninstall packages
#
# 1. install a package
#
# ```pip install *package_name*```
#
# 2. install with speicific version
#
# ```pip install *package_name==version*·```
#
# 3. install packages
#
# ```pip install requirement.txt```
#
# 4. uninstall
#
# ```pip uninstall *package_name*```

# %% [markdown]
# ---

# %% [markdown]
# - ### Upgrade packages
#
# 1. pip
#
# ```
# python.exe -m pip install --upgrade pip
# ```
#
# 2. packages
#
# ```
# pip install --upgrade package_name
# ```

# %% [markdown]
# ---

# %% [markdown]
# - ### Export packages version
#
# 1. to text file
# ```
# pip freeze > requirements.txt
# ```
