# %% [markdown]
# - ### Config
# `git config --global user.name "huazhilianwu"`
#
# `git config --global user.email "huazhilianwu@gmail.com"`
#
# ---

# %% [markdown]
# - ### Connect remote with local
#
# 1. Exsisting remote copy to local
#
# `git clone *SSH key from github*`
#
# 2. Exsisting local to remote
#
# `git init`
#
# `git remote add origin *SSH key from github*`
#
# ---

# %% [markdown]
# - ### Push local update to remote
#
# `git add .`
# `git commit -m ‘update’`
# `git push`
#
# ---

# %% [markdown]
# - ### Pull remote update to local
#
# `git pull origin`
#
# ---

# %% [markdown]
# - ### Branch
# `git branch *branch-name*`
#
# `git switch -c *branch-name*`
#
# `git merge *branch*`
#
# `git branch -d *branch-name*`
#
# ---

# %% [markdown]
# ![image.png](attachment:image.png)
